# %%
# %load_ext autoreload

# dynamic figures
# %matplotlib notebook

# %%
# %autoreload
import two048.display as display

# %%
display.test()
# Out:
# <img src="data:image/png;base64,..." width="800">
